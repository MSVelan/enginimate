# %% [markdown]
# # Orchestrator-Worker Example

# %%
import operator
import os
from typing import Annotated, List

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from pydantic import BaseModel, Field

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_KEY")
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT_NAME"] = "report-planner-groq"

# Schema for structured output to use in planning
class Section(BaseModel):
    name: str = Field(
        description="Name for this section of the report.",
    )
    description: str = Field(
        description="Brief overview of the main topics and concepts to be covered in this section.",
    )


class Sections(BaseModel):
    sections: List[Section] = Field(
        description="Sections of the report.",
    )

llm = init_chat_model("groq:llama-3.1-8b-instant")

# Augment the LLM with schema for structured output
planner = llm.with_structured_output(Sections)

# %%
from typing import TypedDict

from IPython.display import Image, Markdown, display
from langchain.messages import HumanMessage, SystemMessage
from langgraph.graph import END, START, StateGraph
from langgraph.types import Send


# Graph state
class State(TypedDict):
    topic: str  # Report topic
    sections: list[Section]  # List of report sections
    completed_sections: Annotated[
        list, operator.add
    ]  # All workers write to this key in parallel
    final_report: str  # Final report


# Worker state
class WorkerState(TypedDict):
    section: Section
    completed_sections: Annotated[list, operator.add]


# Nodes
def orchestrator(state: State):
    """Orchestrator that generates a plan for the report"""

    # Generate queries
    report_sections = planner.invoke(
        [
            SystemMessage(content="Generate a plan for the report."),
            HumanMessage(content=f"Here is the report topic: {state['topic']}"),
        ]
    )

    return {"sections": report_sections.sections}


def llm_call(state: WorkerState):
    """Worker writes a section of the report"""

    # Generate section
    section = llm.invoke(
        [
            SystemMessage(
                content="Write a report section following the provided name and description. Include no preamble for each section. Use markdown formatting."
            ),
            HumanMessage(
                content=f"Here is the section name: {state['section'].name} and description: {state['section'].description}"
            ),
        ]
    )

    # Write the updated section to completed sections
    return {"completed_sections": [section.content]}


def synthesizer(state: State):
    """Synthesize full report from sections"""

    # List of completed sections
    completed_sections = state["completed_sections"]

    # Format completed section to str to use as context for final sections
    completed_report_sections = "\n\n---\n\n".join(completed_sections)

    return {"final_report": completed_report_sections}


# Conditional edge function to create llm_call workers that each write a section of the report
def assign_workers(state: State):
    """Assign a worker to each section in the plan"""

    # Kick off section writing in parallel via Send() API
    return [Send("llm_call", {"section": s}) for s in state["sections"]]


# Build workflow
orchestrator_worker_builder = StateGraph(State)

# Add the nodes
orchestrator_worker_builder.add_node("orchestrator", orchestrator)
orchestrator_worker_builder.add_node("llm_call", llm_call)
orchestrator_worker_builder.add_node("synthesizer", synthesizer)

# Add edges to connect nodes
orchestrator_worker_builder.add_edge(START, "orchestrator")
orchestrator_worker_builder.add_conditional_edges(
    "orchestrator", assign_workers, ["llm_call"]
)
orchestrator_worker_builder.add_edge("llm_call", "synthesizer")
orchestrator_worker_builder.add_edge("synthesizer", END)

# Compile the workflow
orchestrator_worker = orchestrator_worker_builder.compile()

# Show the workflow
display(Image(orchestrator_worker.get_graph().draw_mermaid_png()))

# Invoke
state = orchestrator_worker.invoke({"topic": "Create a report on LLM scaling laws"})

Markdown(state["final_report"])
# Out:
# ### Introduction and Description: Overview of LLMs and the Importance of Scaling Laws
#
# #### Overview of LLMs
#
# **Definition**: Large Language Models (LLMs) are artificial intelligence models designed to process and generate human-like language. They are typically trained on vast amounts of text data and use complex algorithms to predict the next word or sequence of words in a sentence.
#
# **Key Characteristics**: LLMs are characterized by their:
#
# * **Large Vocabulary**: LLMs have been trained on massive datasets, allowing them to recognize and generate an enormous number of words and phrases.
# * **Deep Neural Networks**: LLMs rely on deep neural networks to process and analyze language data.
# * **Self-Supervised Learning**: LLMs learn by processing and generating text without explicit supervision.
#
# #### Importance of Scaling Laws
#
# **Definition**: Scaling laws refer to the relationships between the size and complexity of LLMs and their performance. As LLMs grow in size, they become increasingly powerful and capable of handling more complex tasks.
#
# **Key Implications**: Understanding scaling laws is crucial for:
#
# * **Model Development**: Scaling laws help developers predict the performance of LLMs and make informed decisions about model size, complexity, and training data.
# * **Resource Allocation**: Scaling laws inform the allocation of computational resources, such as GPU power and memory, to optimize model performance.
# * **Model Deployment**: Scaling laws are essential for deploying LLMs in real-world applications, where model performance and efficiency are critical.
#
# ---
#
# ### Background and Description: History of LLMs and Current State of the Field
#
# #### Early Beginnings of LLMs
#
# * The concept of Large Language Models (LLMs) dates back to the 1950s with the development of artificial neural networks and the perceptron.
# * In the 1980s, the first neural network language models were introduced, using backpropagation to train neural networks on text data.
# * However, it wasn't until the 2010s that LLMs began to gain significant attention with the introduction of deep learning techniques and large-scale datasets.
#
# #### Rise of Deep Learning and LLMs
#
# * The introduction of Long Short-Term Memory (LSTM) networks and other recurrent neural networks (RNNs) in the 1990s and 2000s paved the way for more sophisticated language models.
# * In the early 2010s, the development of word embeddings (e.g., Word2Vec, GloVe) and pre-training techniques (e.g., language modeling pre-training) further improved the performance of LLMs.
# * The release of the Transformer architecture in 2017 revolutionized the field of NLP, enabling faster and more efficient training of LLMs.
#
# #### Current State of the Field
#
# * Today, LLMs are widely used in various applications, including language translation, text summarization, question answering, and conversational AI.
# * The development of more powerful computing infrastructure, such as GPUs and TPUs, has enabled the training of larger and more complex LLMs.
# * The introduction of new techniques, such as masked language modeling and contrastive learning, has further improved the performance of LLMs.
# * However, the current state of the field is also marked by challenges, including the risk of bias, lack of transparency, and the need for more robust evaluation metrics.
#
# #### Key Players and Research Directions
#
# * Companies like Google, Microsoft, and Meta have been at the forefront of LLM research and development, releasing high-profile models like BERT, RoBERTa, and PaLM.
# * Research institutions and universities are also actively contributing to the advancement of LLMs, exploring new techniques and applications.
# * Some of the key research directions in the field include multimodal LLMs, few-shot learning, and explainability.
#
# ---
#
# ### Scaling Laws for Large Language Models (LLMs)
# #### Definition
# Scaling laws for LLMs refer to mathematical relationships that describe how the performance of a language model changes as its size, complexity, or computational resources increase. These laws provide a framework for understanding the trade-offs between model size, computational requirements, and performance.
#
# #### Types of Scaling Laws
# There are several types of scaling laws that have been proposed for LLMs:
#
# ##### 1. **Neural Tangent Kernel (NTK) Scaling Law**
# The NTK scaling law describes the behavior of neural networks in the limit of infinite width. It shows that the test error of a neural network decreases as the number of parameters increases, but at a slower rate than the capacity of the network.
#
# ##### 2. **Scaling Law of Neural Network Capacity**
# This scaling law relates the capacity of a neural network to its size and complexity. It shows that the capacity of a neural network increases exponentially with the number of parameters.
#
# ##### 3. **Model-Parallelism Scaling Law**
# This scaling law describes the performance of a language model when it is parallelized across multiple GPUs or machines. It shows that the performance of the model increases as the number of parallelization nodes increases, but at a cost of increased communication overhead.
#
# ##### 4. **Data-Parallelism Scaling Law**
# This scaling law describes the performance of a language model when it is parallelized across multiple data samples. It shows that the performance of the model increases as the number of parallelization nodes increases, but at a cost of increased memory requirements.
#
# ##### 5. **Capacity-Computational Resource Trade-off**
# This scaling law describes the trade-off between the capacity of a language model and the computational resources required to train it. It shows that the capacity of a language model increases as the computational resources increase, but at a cost of increased training time.
#
# #### Implications of Scaling Laws
# The scaling laws for LLMs have important implications for the design and training of large language models. They provide a framework for understanding the trade-offs between model size, computational requirements, and performance, and can help guide the development of more efficient and effective language models.
#
# ---
#
# ### Application of Scaling Laws
#
# #### Real-world Applications and Case Studies of LLM Scaling Laws
#
# ##### 1. **Transformers and Large Language Models**
#
# *   **BERT and Its Variants**: Google's BERT (Bidirectional Encoder Representations from Transformers) and its variants, such as RoBERTa and ALBERT, have demonstrated exceptional performance in NLP tasks. These models are built using transformer architecture, which scales well with increasing input size and compute resources.
# *   **Case Study**: BERT's success can be attributed to its ability to scale up to large input sizes, allowing it to capture complex relationships in text data. This scalability has been a key factor in its adoption across various industries.
#
# ##### 2. **Recommendation Systems**
#
# *   **Neural Collaborative Filtering (NCF)**: NCF is a state-of-the-art algorithm for building recommendation systems. It uses a neural network architecture that scales well with increasing user and item interactions. By leveraging large-scale data and compute resources, NCF can generate accurate and personalized recommendations.
# *   **Case Study**: Companies like Netflix and Amazon have successfully implemented NCF-based recommendation systems, resulting in improved user engagement and increased revenue.
#
# ##### 3. **Speech Recognition**
#
# *   **Deep Speech**: Google's Deep Speech is a neural network-based speech recognition system that scales well with increasing audio data and compute resources. By using large-scale datasets and advanced neural architectures, Deep Speech can achieve state-of-the-art performance in speech recognition tasks.
# *   **Case Study**: Deep Speech has been widely adopted in various applications, including voice assistants and smart speakers, demonstrating the scalability of neural networks in speech recognition tasks.
#
# ##### 4. **Computer Vision**
#
# *   **ResNet and Its Variants**: ResNet is a popular neural network architecture for computer vision tasks that scales well with increasing image sizes and compute resources. By leveraging large-scale datasets and advanced neural architectures, ResNet and its variants can achieve state-of-the-art performance in image classification, object detection, and segmentation tasks.
# *   **Case Study**: ResNet's success can be attributed to its ability to scale up to large image sizes, allowing it to capture complex visual features and patterns. This scalability has been a key factor in its adoption across various industries, including self-driving cars and medical imaging.
#
# ##### 5. **Generative Models**
#
# *   **Generative Adversarial Networks (GANs)**: GANs are a type of deep learning model that scales well with increasing input size and compute resources. By leveraging large-scale datasets and advanced neural architectures, GANs can generate realistic and diverse samples in various domains, including images, videos, and music.
# *   **Case Study**: GANs have been widely adopted in various applications, including image and video generation, data augmentation, and style transfer, demonstrating the scalability of neural networks in generative tasks.
#
# In conclusion, LLM scaling laws have numerous real-world applications and case studies in various domains, including NLP, recommendation systems, speech recognition, computer vision, and generative models. By leveraging large-scale data and compute resources, these models can achieve state-of-the-art performance and have a significant impact on various industries.
#
# ---
#
# ## Future Outlook
# ### Emerging Trends and Future Directions in LLM Scaling Laws
#
# #### 1. **Advancements in Computational Power**
# The rapid growth of computing hardware, such as graphics processing units (GPUs) and tensor processing units (TPUs), will continue to drive advancements in LLM scaling laws. Future LLMs are expected to leverage emerging technologies like quantum computing, neuromorphic chips, and specialized AI accelerators to achieve significant performance boosts.
#
# #### 2. **Efficient Model Architectures**
# Researchers will focus on developing more efficient model architectures that can reduce the computational requirements and memory footprints of LLMs. This will enable the training and deployment of larger models on a wider range of devices, from small edge devices to large-scale data centers.
#
# #### 3. **Data Efficiency and Active Learning**
# As data storage and transfer costs continue to rise, there will be a growing emphasis on data-efficient LLMs. Active learning techniques, which selectively sample the most informative data points, will become increasingly important to reduce the need for massive amounts of training data.
#
# #### 4. **Interpretability and Explainability**
# As LLMs become more prevalent, there is a growing need for techniques that can provide insights into their decision-making processes. Future research will focus on developing methods for interpreting and explaining the behavior of LLMs, which will help build trust in their outputs.
#
# #### 5. **Multimodal Learning and Transfer Learning**
# The integration of multimodal data (e.g., text, images, audio) will become increasingly important in LLMs. Transfer learning, which leverages pre-trained models as a starting point for new tasks, will also become more prominent, enabling faster training and adaptation to new domains.
#
# #### 6. **Autoregressive and Non-Autoregressive Models**
# Autoregressive models, which generate output one token at a time, will continue to be a popular choice for LLMs. However, non-autoregressive models, which generate output in parallel, will gain traction due to their faster inference times and lower latency.
#
# #### 7. **Scalable Hyperparameter Tuning**
# The search space for hyperparameters in LLMs is vast, and manual tuning is often time-consuming and labor-intensive. Future research will focus on developing scalable hyperparameter tuning methods that can efficiently explore this space and identify optimal configurations.
#
# #### 8. **Model-Parallelism and Data-Parallelism**
# As LLMs continue to grow in size and complexity, model-parallelism (splitting the model across multiple devices) and data-parallelism (splitting the data across multiple devices) will become increasingly important to achieve efficient training and inference.
#
# ---
#
# ### Conclusion and description: Summary and final thoughts on LLM scaling laws
#
# #### Summary
#
# The investigation into Large Language Model (LLM) scaling laws has provided valuable insights into the factors influencing the performance of these complex systems. The analysis of various studies and datasets has revealed a strong positive correlation between model size and performance, particularly in terms of accuracy and language understanding. This suggests that larger models are capable of capturing more nuanced and complex patterns in language data.
#
# #### Key Findings
#
# *   A significant positive relationship exists between model size and performance, indicating that larger models tend to outperform smaller ones.
# *   The relationship between model size and performance is not linear, but rather exhibits a more complex, non-linear behavior.
# *   The scaling law for LLMs appears to be governed by a power-law relationship, with a scaling exponent that is dependent on the specific task and model architecture.
# *   The performance of LLMs is also influenced by other factors, including the quality and diversity of the training data, as well as the model's architecture and hyperparameters.
#
# #### Implications and Future Directions
#
# The findings of this study have important implications for the development and deployment of LLMs in various applications. To maximize the performance of these systems, it is essential to consider the optimal model size and architecture for a given task, as well as the quality and diversity of the training data. Furthermore, the scaling law for LLMs highlights the need for more efficient and effective methods for training and fine-tuning these models, particularly as model sizes continue to grow.
#
# #### Final Thoughts
#
# In conclusion, the investigation into LLM scaling laws has provided a deeper understanding of the factors influencing the performance of these complex systems. As the field continues to evolve, it is essential to consider the implications of these findings and to develop more efficient and effective methods for training and deploying LLMs. By doing so, we can unlock the full potential of these systems and realize their promise in a wide range of applications.

# %% [markdown]
# # Evaluator-Optimizer example

# %%
import os
from typing import Literal, TypedDict

from dotenv import load_dotenv
from IPython.display import Image, display
from langchain.chat_models import init_chat_model
from langgraph.graph import END, START, StateGraph
from pydantic import BaseModel, Field

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_KEY")
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT_NAME"] = "joke-optimizer-groq"

llm = init_chat_model("groq:llama-3.1-8b-instant")

# Graph state
class State(TypedDict):
    joke: str
    topic: str
    feedback: str
    funny_or_not: str


# Schema for structured output to use in evaluation
class Feedback(BaseModel):
    grade: Literal["funny", "not funny"] = Field(
        description="Decide if the joke is funny or not.",
    )
    feedback: str = Field(
        description="If the joke is not funny, provide feedback on how to improve it.",
    )


# Augment the LLM with schema for structured output
evaluator = llm.with_structured_output(Feedback)


# Nodes
def llm_call_generator(state: State):
    """LLM generates a joke"""

    if state.get("feedback"):
        msg = llm.invoke(
            f"Write a joke about {state['topic']} but take into account the feedback: {state['feedback']}"
        )
    else:
        msg = llm.invoke(f"Write a joke about {state['topic']}")
    return {"joke": msg.content}


def llm_call_evaluator(state: State):
    """LLM evaluates the joke"""

    grade = evaluator.invoke(f"Grade the joke {state['joke']}")
    return {"funny_or_not": grade.grade, "feedback": grade.feedback}


# Conditional edge function to route back to joke generator or end based upon feedback from the evaluator
def route_joke(state: State):
    """Route back to joke generator or end based upon feedback from the evaluator"""

    if state["funny_or_not"] == "funny":
        return "Accepted"
    elif state["funny_or_not"] == "not funny":
        return "Rejected + Feedback"


# Build workflow
optimizer_builder = StateGraph(State)

# Add the nodes
optimizer_builder.add_node("llm_call_generator", llm_call_generator)
optimizer_builder.add_node("llm_call_evaluator", llm_call_evaluator)

# Add edges to connect nodes
optimizer_builder.add_edge(START, "llm_call_generator")
optimizer_builder.add_edge("llm_call_generator", "llm_call_evaluator")
optimizer_builder.add_conditional_edges(
    "llm_call_evaluator",
    route_joke,
    {  # Name returned by route_joke : Name of next node to visit
        "Accepted": END,
        "Rejected + Feedback": "llm_call_generator",
    },
)

# Compile the workflow
optimizer_workflow = optimizer_builder.compile()

# Show the workflow
display(Image(optimizer_workflow.get_graph().draw_mermaid_png()))

# Invoke
state = optimizer_workflow.invoke({"topic": "Cats"})
print(state["joke"])
# Out:
# Why did the cat join a band?
#
# Because it wanted to be the purr-cussionist.
